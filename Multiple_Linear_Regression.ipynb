# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df=pd.read_csv('50_Startups.csv')

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df['State'].unique()
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
df['State'] = df['State'].map({'New York':0,'California':1,'Florida':2}).astype(int)

# %%
df['State'].value_counts()
# Out:
# State
# 0    17
# 1    17
# 2    16
# Name: count, dtype: int64

# %%
X=df.iloc[: ,:-1]
y=df.iloc[ : , -1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=sklearn.model_selection.train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#     R&D Spend  Administration  Marketing Spend  State
# 32   63408.86       129219.61         46085.25      1
# 39   38558.51        82982.09        174999.30      1
# 21   78389.47       153773.43        299737.29      0
# 36   28663.76       127056.21        201126.82      2
# 19   86419.70       153514.11             0.00      0
# 42   23640.93        96189.63        148001.11      1
# 49       0.00       116983.80         45173.06      1
# 26   75328.87       144135.98        134050.07      2
# 22   73994.56       122782.75        303319.26      2
# 13   91992.39       135495.07        252664.93      1
# 41   27892.92        84710.77        164470.71      2
# 17   94657.16       145077.58        282574.31      0
# 45    1000.23       124153.04          1903.93      0
# 24   77044.01        99281.34        140574.81      0
# 23   67532.53       105751.03        304768.73      2
# 4   142107.34        91391.77        366168.42      2
# ...

# %%
len(X_train),len(y_train)
# Out:
# (40, 40)

# %%
len(X_test),len(y_test)
# Out:
# (10, 10)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Traing Performance**

# %%
y_train_pred=lm.predict(X_train)
y_train_pred
# Out:
# array([ 98985.93327603,  83873.28876931, 117575.12515222,  76776.76439896,
#        115082.57061532,  71416.19659812,  49929.54180198, 110840.17400213,
#        114911.11320905, 127089.13138529,  75474.38383966, 129755.59360661,
#         49198.51976827, 112368.19691262, 110091.17296557, 169785.69134349,
#         98164.34401058, 148866.66061678,  99502.35248924, 134491.74936526,
#        102860.5904782 ,  66302.45932481,  90373.89963741, 128497.86026895,
#        116415.85398097, 102543.02901776, 156383.21530373, 158943.49701797,
#         48458.55365865, 187225.90216113, 116715.08179609, 190105.84064858,
#        144736.28983823, 161317.21524898, 134102.38895242, 153125.88032268,
#        150627.10068872, 128713.2949918 ,  61389.05651809,  89054.91601833])

# %%
Training_data_prediction=pd.DataFrame()
Training_data_prediction=X_train.copy()
Training_data_prediction['Actual Value']=y_train.copy()
Training_data_prediction['Predicted Value']=y_train_pred
Training_data_prediction
# Out:
#     R&D Spend  Administration  Marketing Spend  State  Actual Value  \
# 32   63408.86       129219.61         46085.25      1      97427.84
# 39   38558.51        82982.09        174999.30      1      81005.76
# 21   78389.47       153773.43        299737.29      0     111313.02
# 36   28663.76       127056.21        201126.82      2      90708.19
# 19   86419.70       153514.11             0.00      0     122776.86
# 42   23640.93        96189.63        148001.11      1      71498.49
# 49       0.00       116983.80         45173.06      1      14681.40
# 26   75328.87       144135.98        134050.07      2     105733.54
# 22   73994.56       122782.75        303319.26      2     110352.25
# 13   91992.39       135495.07        252664.93      1     134307.35
# 41   27892.92        84710.77        164470.71      2      77798.83
# 17   94657.16       145077.58        282574.31      0     125370.37
# 45    1000.23       124153.04          1903.93      0      64926.08
# ...

# %%
Training_data_prediction.shape
# Out:
# (40, 6)

# %%
#alog   y=m1x1+m2x2+m3x3+m4x4+c

lm.coef_ # m values
# Out:
# array([ 7.74878648e-01, -8.52492210e-03,  2.90828645e-02,  1.86571447e+02])

# %%
# c value
lm.intercept_
# Out:
# 49426.486154142236

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
mean_squared_error(y_train,y_train_pred)
# Out:
# 80079540.61681831

# %%
r2_score(y_train,y_train_pred)
# Out:
# 0.9424169581402101

# %% [markdown]
# **Training Data Performance**

# %% [markdown]
# **Normal Calculations**

# %%
Training_data_prediction.index
# Out:
# Index([32, 39, 21, 36, 19, 42, 49, 26, 22, 13, 41, 17, 45, 24, 23,  4, 33, 14,
#        30, 10, 28, 44, 34, 18, 20, 25,  6,  7, 47,  1, 16,  0, 15,  5, 11,  9,
#         8, 12, 43, 37],
#       dtype='int64')

# %% [markdown]
# **Mean_square_error calculation**

# %%
#mean_square_error
count=0
for i in Training_data_prediction.index:
  count=count + (Training_data_prediction['Actual Value'][i]-Training_data_prediction['Predicted Value'][i])**2
print(count/len(Training_data_prediction))
# Out:
# 80079540.61681828

# %% [markdown]
# **r2_score Calculation**

# %%
y_train.index
# Out:
# Index([32, 39, 21, 36, 19, 42, 49, 26, 22, 13, 41, 17, 45, 24, 23,  4, 33, 14,
#        30, 10, 28, 44, 34, 18, 20, 25,  6,  7, 47,  1, 16,  0, 15,  5, 11,  9,
#         8, 12, 43, 37],
#       dtype='int64')

# %%
y_train.shape
# Out:
# (40,)

# %%
sum(y_train)
# Out:
# 4582070.43

# %%
#y_train -> sum of y_train or mean of y_train
count=0
for i in Training_data_prediction.index:
  count=count+Training_data_prediction['Actual Value'][i]
print(count)
# Out:
# 4582070.43

# %%
#r2_score
sum=4582070.43
count=0
for i in Training_data_prediction.index:
  count=count+((Training_data_prediction['Actual Value'][i]-Training_data_prediction['Predicted Value'][i]**2)/(Training_data_prediction['Actual Value'][i]-sum**2))
print(1-count)
# Out:
# 0.9725032871118193

# %%
r2_score(y_train,y_train_pred)
# Out:
# 0.9424169581402101

# %%
lm.coef_
# Out:
# array([ 7.74878648e-01, -8.52492210e-03,  2.90828645e-02,  1.86571447e+02])

# %%
lm.intercept_l
# Out:
# 49426.486154142236

# %% [markdown]
# **Alogorithm:
#
#  is y=m1x1+m2x2+m3x3+m4x4+c**

# %%
m1,m2,m3,m4=lm.coef_

# %%
c=lm.intercept_

# %%
Training_data_prediction
# Out:
#     R&D Spend  Administration  Marketing Spend  State  Actual Value  \
# 32   63408.86       129219.61         46085.25      1      97427.84
# 39   38558.51        82982.09        174999.30      1      81005.76
# 21   78389.47       153773.43        299737.29      0     111313.02
# 36   28663.76       127056.21        201126.82      2      90708.19
# 19   86419.70       153514.11             0.00      0     122776.86
# 42   23640.93        96189.63        148001.11      1      71498.49
# 49       0.00       116983.80         45173.06      1      14681.40
# 26   75328.87       144135.98        134050.07      2     105733.54
# 22   73994.56       122782.75        303319.26      2     110352.25
# 13   91992.39       135495.07        252664.93      1     134307.35
# 41   27892.92        84710.77        164470.71      2      77798.83
# 17   94657.16       145077.58        282574.31      0     125370.37
# 45    1000.23       124153.04          1903.93      0      64926.08
# ...

# %%
Training_data_prediction['Actual Value'][37]
# Out:
# 89949.14

# %%
X_train.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State'], dtype='object')

# %% [markdown]
# **Calculate Predicted value using m,x,c values**
#
#
# 'one row of X_train data'

# %%
lm.coef_[0]*44069.95+lm.coef_[1]*51283.14+lm.coef_[2]*197029.42	+ lm.coef_[3]*1+lm.intercept_
# Out:
# 89054.91601832892

# %% [markdown]
# **Testing Data Performance**

# %%
y_test_pred=lm.predict(X_test)
y_test_pred
# Out:
# array([114482.68730189,  90333.7866289 ,  75908.97116585,  69927.80233176,
#        179699.82586154, 171430.45835272,  49405.40280247, 102074.07638902,
#         58472.56632227,  98063.628483  ])

# %%
Testing_Data_predicted=pd.DataFrame()
Testing_Data_predicted=X_test.copy()
Testing_Data_predicted['Actual value']=y_test.copy()
Testing_Data_predicted['Predicted value']=y_test_pred
Testing_Data_predicted
# Out:
#     R&D Spend  Administration  Marketing Spend  State  Actual value  \
# 27   72107.60       127864.55        353183.81      0     105008.31
# 35   46014.02        85047.44        205517.64      0      96479.51
# 40   28754.33       118546.05        172795.67      1      78239.91
# 38   20229.59        65947.93        185265.10      0      81229.06
# 2   153441.51       101145.55        407934.54      2     191050.39
# 3   144372.41       118671.85        383199.62      0     182901.99
# 48     542.05        51743.15             0.00      0      35673.41
# 29   65605.48       153032.06        107138.38      0     101004.64
# 46    1315.46       115816.21        297114.46      2      49490.75
# 31   61136.38       152701.92         88218.23      0      97483.56
#
#     Predicted value
# 27    114482.687302
# 35     90333.786629
# 40     75908.971166
# 38     69927.802332
# 2     179699.825862
# 3     171430.458353
# 48     49405.402802
# 29    102074.076389
# 46     58472.566322
# ...

# %%
r2_score(y_test,y_test_pred)
# Out:
# 0.9650991796290039

# %%
mean_squared_error(y_test,y_test_pred)
# Out:
# 79183761.0750145
